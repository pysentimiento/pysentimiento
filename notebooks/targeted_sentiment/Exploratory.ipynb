# %%
# %load_ext autoreload
# %autoreload 2

from pysentimiento.targeted_sa import load_datasets

ds = load_datasets("es")

ds
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# WARNING:datasets.builder:Using custom data configuration finiteautomata--tsa-599a441ee2b1c24d
# WARNING:datasets.builder:Found cached dataset parquet (/users/jmperez/.cache/huggingface/datasets/pysentimiento___parquet/finiteautomata--tsa-599a441ee2b1c24d/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['titulo', 'id_noticia', 'target', 'label'],
#         num_rows: 1514
#     })
#     dev: Dataset({
#         features: ['titulo', 'id_noticia', 'target', 'label'],
#         num_rows: 395
#     })
#     test: Dataset({
#         features: ['titulo', 'id_noticia', 'target', 'label'],
#         num_rows: 530
#     })
# })

# %%
ds["train"][0]
# Out:
# {'titulo': 'Mi foto con un ajustador: Alberto Fernández pasó por Mendoza y posó junto a Mariano Arcioni',
#  'id_noticia': 488,
#  'target': 'Alberto Fernández',
#  'label': 0}

# %%
id2label = {k: v for k, v in enumerate(ds["train"].features["label"].names)}

# %%
from pysentimiento.targeted_sa import load_model
model_name = "pysentimiento/robertuito-base-uncased"

model, tokenizer = load_model(model_name, id2label, lang="es")
# Out:
# Some weights of the model checkpoint at pysentimiento/robertuito-base-uncased were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['titulo', 'id_noticia', 'target', 'label'],
#         num_rows: 1521
#     })
#     dev: Dataset({
#         features: ['titulo', 'id_noticia', 'target', 'label'],
#         num_rows: 381
#     })
#     test: Dataset({
#         features: ['titulo', 'id_noticia', 'target', 'label'],
#         num_rows: 537
#     })
# })

# %%
tokenized_ds = ds.map(
    lambda batch: tokenizer(
        batch['titulo'], batch["target"], padding='max_length', truncation=True), batched=True, batch_size=32
    )
# Out:
# ...
#   0%|          | 0/17 [00:00<?, ?ba/s]

# %%
[len(l) for l in tokenized_ds["train"]["input_ids"]]
# Out:
# [128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
#  128,
# ...
