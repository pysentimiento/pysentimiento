# %% [markdown]
# # pysentimiento: A transformer-based Sentiment Analysis library for Spanish
#
# En esta notebook mostramos un breve ejemplo de cómo usar [pysentimiento](https://github.com/pysentimiento/pysentimiento/), un toolkit multilingual para extracción de opiniones y análisis de sentimientos (aunque centrado en el idioma español)
#
# `pysentimiento` es un una librería que utiliza modelos pre-entrenados de [transformers](https://github.com/huggingface/transformers) para distintas tareas de SocialNLP. Usa como modelos bases a [BETO](https://github.com/dccuchile/beto) y [RoBERTuito](https://github.com/pysentimiento/robertuito) en Español, y BERTweet en inglés.
#
# --
#
# In this notebook we show a brief example of how to use [pysentimiento](https://github.com/pysentimiento/pysentimiento/), a multilingual toolkit for opinion mining and sentiment analysis.
#
# `pysentimiento` is a library that uses pre-trained models of [transformers] (https://github.com/huggingface/transformers) for different SocialNLP tasks. It uses as base models [BETO] (https://github.com/dccuchile/beto) and [RoBERTuito] (https://github.com/pysentimiento/robertuito) in Spanish, and BERTweet in English.
#
#
# First, let's install the library

# %%
# !pip install pysentimiento
# Out:
# Requirement already satisfied: pysentimiento in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (0.2.5)
# Requirement already satisfied: emoji<2.0.0,>=1.6.1 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from pysentimiento) (1.6.1)
# Requirement already satisfied: sklearn<0.1,>=0.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from pysentimiento) (0.0)
# Requirement already satisfied: torch<2.0.0,>=1.9.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from pysentimiento) (1.10.0)
# Requirement already satisfied: transformers<5.0.0,>=4.11.3 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from pysentimiento) (4.11.3)
# Requirement already satisfied: datasets<2.0.0,>=1.13.3 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from pysentimiento) (1.14.0)
# Requirement already satisfied: multiprocess in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (0.70.12.2)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (2021.11.0)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (5.0.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (4.62.3)
# Requirement already satisfied: aiohttp in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (3.7.4.post0)
# Requirement already satisfied: pandas in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (1.1.5)
# Requirement already satisfied: dill in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (0.3.4)
# Requirement already satisfied: packaging in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (21.0)
# Requirement already satisfied: xxhash in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (2.0.2)
# Requirement already satisfied: numpy>=1.17 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (1.21.3)
# Requirement already satisfied: requests>=2.19.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (2.26.0)
# Requirement already satisfied: huggingface-hub<0.1.0,>=0.0.19 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (0.0.19)
# Requirement already satisfied: importlib-metadata in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (4.8.1)
# Requirement already satisfied: scikit-learn in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from sklearn<0.1,>=0.0->pysentimiento) (1.0)
# Requirement already satisfied: typing-extensions in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from torch<2.0.0,>=1.9.0->pysentimiento) (3.10.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from transformers<5.0.0,>=4.11.3->pysentimiento) (6.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from transformers<5.0.0,>=4.11.3->pysentimiento) (0.10.3)
# Requirement already satisfied: filelock in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from transformers<5.0.0,>=4.11.3->pysentimiento) (3.3.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from transformers<5.0.0,>=4.11.3->pysentimiento) (2021.10.21)
# Requirement already satisfied: sacremoses in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from transformers<5.0.0,>=4.11.3->pysentimiento) (0.0.46)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from packaging->datasets<2.0.0,>=1.13.3->pysentimiento) (2.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (2021.10.8)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (1.7.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (3.0.1)
# Requirement already satisfied: chardet<5.0,>=2.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (4.0.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (21.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from importlib-metadata->datasets<2.0.0,>=1.13.3->pysentimiento) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from pandas->datasets<2.0.0,>=1.13.3->pysentimiento) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from pandas->datasets<2.0.0,>=1.13.3->pysentimiento) (2021.3)
# Requirement already satisfied: joblib in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from sacremoses->transformers<5.0.0,>=4.11.3->pysentimiento) (1.1.0)
# Requirement already satisfied: six in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from sacremoses->transformers<5.0.0,>=4.11.3->pysentimiento) (1.16.0)
# Requirement already satisfied: click in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from sacremoses->transformers<5.0.0,>=4.11.3->pysentimiento) (8.0.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from scikit-learn->sklearn<0.1,>=0.0->pysentimiento) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/lib/python3.7/site-packages (from scikit-learn->sklearn<0.1,>=0.0->pysentimiento) (1.7.1)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/jmperez/.cache/pypoetry/virtualenvs/pysentimiento-bwlKzHxB-py3.7/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# Let's create an analyzer. The `create_analyzer` receives the task and the language as parameters (currently supports "es" and "en").

# %%
from pysentimiento import create_analyzer
analyzer = create_analyzer(task="sentiment", lang="es")

# %% [markdown]
# Veamos algunos ejemplos:

# %%
analyzer.predict("Qué gran jugador es Messi")
# Out:
# AnalyzerOutput(output=POS, probas={POS: 0.994, NEG: 0.003, NEU: 0.003})

# %%
analyzer.predict("Esto es pésimo")
# Out:
# AnalyzerOutput(output=NEG, probas={NEG: 0.948, NEU: 0.048, POS: 0.004})

# %%
analyzer.predict("Qué es esto?")
# Out:
# AnalyzerOutput(output=NEU, probas={NEU: 0.802, NEG: 0.188, POS: 0.010})

# %% [markdown]
# ### Predicción en batch
#
# Si tenemos un conjunto de oraciones, `pysentimiento` hace la predicción en conjunto de manera eficiente

# %%
# %%time
from tqdm.auto import tqdm
oraciones = [
    "Qué gran jugador es Messi",
    "Esto es pésimo",
    "No sé, cómo se llama?",    
] * 100
for sent in tqdm(oraciones):
    analyzer.predict(sent)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# CPU times: user 2.75 s, sys: 16 ms, total: 2.76 s
# Wall time: 2.74 s

# %%
# %%time
rets = analyzer.predict(oraciones)
# Out:
#   0%|          | 0/10 [00:00<?, ?ba/s]
# The following columns in the test set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: text.
# ***** Running Prediction *****
#   Num examples = 300
#   Batch size = 32
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 00:00]
#     </div>
# CPU times: user 892 ms, sys: 404 ms, total: 1.3 s
# Wall time: 1.18 s

# %% [markdown]
# ### Emojis
#
# It supports the use of emojis through the [emoji](https://pypi.org/project/emoji/) library.
#
# Soporta también el uso de emojis

# %%
analyzer.predict("🤢")
# Out:
# AnalyzerOutput(output=NEG, probas={NEG: 0.981, NEU: 0.017, POS: 0.002})

# %% [markdown]
# O de hashtags

# %%
analyzer.predict("#EstoEsUnaMierda")
# Out:
# AnalyzerOutput(output=NEG, probas={NEG: 0.998, NEU: 0.001, POS: 0.001})

# %% [markdown]
# ## Emotion Analysis
#
# `pysentimiento` provee análisis de emociones a través de modelos pre-entrenados con los datasets de [EmoEvent](https://github.com/fmplaza/EmoEvent-multilingual-corpus/)

# %%
emotion_analyzer = create_analyzer(task="emotion", lang="en")
# Out:
# loading configuration file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/config.json from cache at /home/jmperez/.cache/huggingface/transformers/c246eed05359b1a49c45955b0265b488e35b0cbd2628e3ead7dd54c8815162ee.a2dff24b4e0a884c6d58a09968c5b68e7391e749eb698ad92541818d420fd01b
# Model config RobertaConfig {
#   "_name_or_path": "vinai/bertweet-base",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "others",
#     "1": "joy",
#     "2": "sadness",
#     "3": "anger",
#     "4": "surprise",
#     "5": "disgust",
#     "6": "fear"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "anger": 3,
#     "disgust": 5,
#     "fear": 6,
#     "joy": 1,
#     "others": 0,
#     "sadness": 2,
#     "surprise": 4
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertweetTokenizer",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64001
# }
#
# loading file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/vocab.txt from cache at /home/jmperez/.cache/huggingface/transformers/b7837213513a9f3852dcb04048f70c13cbd0590be030e534734ffd42cbdcf45a.f8a4dfe5c3c45a26f9df849d732decb191dc0c05ab270799695430332d143982
# loading file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/bpe.codes from cache at /home/jmperez/.cache/huggingface/transformers/76e357e2554ebe053d1c4c613506bc2cc19d66ae27fec8218261a7f73c6456b9.75877d86011e5d5d46614d3a21757b705e9d20ed45a019805d25159b4837b0a4
# loading file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/added_tokens.json from cache at /home/jmperez/.cache/huggingface/transformers/c4b7522f44ed8adb95e62288c6458da591654f7466e3ce2f9c730bb4087411d2.c1e7052e39d2135302ec27455f6db22e1520e6539942ff60a849c7f83f8ec6dc
# loading file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/special_tokens_map.json from cache at /home/jmperez/.cache/huggingface/transformers/01581144d9bf96cb9c7d8a77ee93c8b1f1095af5c1204b1b038a8cb0e3247aa8.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# loading file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/tokenizer_config.json from cache at /home/jmperez/.cache/huggingface/transformers/1740697312c59fe96586f476c7765cd6f08516a6102ea96f22ffee64f7553234.c260b44e952f7f2a825aac395f2ebbed4ac9553800d1e320af246e81a548f37c
# loading file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/tokenizer.json from cache at None
# loading configuration file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/config.json from cache at /home/jmperez/.cache/huggingface/transformers/c246eed05359b1a49c45955b0265b488e35b0cbd2628e3ead7dd54c8815162ee.a2dff24b4e0a884c6d58a09968c5b68e7391e749eb698ad92541818d420fd01b
# Model config RobertaConfig {
#   "_name_or_path": "vinai/bertweet-base",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "others",
#     "1": "joy",
#     "2": "sadness",
#     "3": "anger",
#     "4": "surprise",
#     "5": "disgust",
#     "6": "fear"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "anger": 3,
#     "disgust": 5,
#     "fear": 6,
#     "joy": 1,
#     "others": 0,
#     "sadness": 2,
#     "surprise": 4
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertweetTokenizer",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64001
# }
#
# Adding <mask> to the vocabulary
# loading configuration file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/config.json from cache at /home/jmperez/.cache/huggingface/transformers/c246eed05359b1a49c45955b0265b488e35b0cbd2628e3ead7dd54c8815162ee.a2dff24b4e0a884c6d58a09968c5b68e7391e749eb698ad92541818d420fd01b
# Model config RobertaConfig {
#   "_name_or_path": "vinai/bertweet-base",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "others",
#     "1": "joy",
#     "2": "sadness",
#     "3": "anger",
#     "4": "surprise",
#     "5": "disgust",
#     "6": "fear"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "anger": 3,
#     "disgust": 5,
#     "fear": 6,
#     "joy": 1,
#     "others": 0,
#     "sadness": 2,
#     "surprise": 4
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertweetTokenizer",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64001
# }
#
# loading weights file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/pytorch_model.bin from cache at /home/jmperez/.cache/huggingface/transformers/61c5894a0aca5ed63159e2ec6a5501db48124c1e6de287b82bc634334f031203.9c3c4c16d0dd174434d42471b9d4670734d982be506a06fc3111c12bee4380c7
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at finiteautomata/bertweet-base-emotion-analysis.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
emotion_analyzer.predict("This is so terrible...")
# Out:
# AnalyzerOutput(output=sadness, probas={sadness: 0.978, fear: 0.013, disgust: 0.003, others: 0.002, surprise: 0.002, anger: 0.001, joy: 0.001})

# %%
emotion_analyzer.predict("omg")
# Out:
# AnalyzerOutput(output=surprise, probas={surprise: 0.982, others: 0.007, fear: 0.003, joy: 0.003, sadness: 0.002, anger: 0.002, disgust: 0.001})

# %%
emotion_analyzer.predict("yayyyy")
# Out:
# AnalyzerOutput(output=joy, probas={joy: 0.879, others: 0.106, surprise: 0.005, anger: 0.005, sadness: 0.002, disgust: 0.002, fear: 0.002})

# %%
emotion_analyzer.predict("People in the world is really worried because of Coronavirus")
# Out:
# AnalyzerOutput(output=fear, probas={fear: 0.939, others: 0.043, surprise: 0.005, joy: 0.004, disgust: 0.004, sadness: 0.002, anger: 0.002})

# %% [markdown]
# ## Hate Speech

# %%
hate_speech_analyzer = create_analyzer(task="hate_speech", lang="es")
# Out:
# loading file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/special_tokens_map.json from cache at /home/jmperez/.cache/huggingface/transformers/29bbf6eb913fdd3d8aaabeec43896b21a574167c27d3a9a85fc9dc57eea39ace.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# loading file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/tokenizer_config.json from cache at /home/jmperez/.cache/huggingface/transformers/f151cdb0362e2cc8c419bd5878232bea313009ac93445c0f66bf43ea764cd71c.50a2bcf7668df2ff5a82b7b0455533bb4c0db21e6e33565fa20fd7dc8a3be740
# loading file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/tokenizer.json from cache at /home/jmperez/.cache/huggingface/transformers/82bf0643b37bd3be5cb16b6646358a7e6c7de8829f035e79cdc14ad408ebf3ce.0843b07596b388e054bae078721182b4846b9e28a7bbf04d7079b274f8613ae3
# loading configuration file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/config.json from cache at /home/jmperez/.cache/huggingface/transformers/c798fcd43b0ff166a11ccb606e916eed37ea5800b4dd20ff2edd880fdb8a5cbd.29b427f0b44d35a50b9f730f9e93dbf914ed3fb60537c82b311e1f4732dfdcca
# Model config RobertaConfig {
#   "_name_or_path": "pysentimiento/robertuito-base-uncased",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "hateful",
#     "1": "targeted",
#     "2": "aggressive"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "aggressive": 2,
#     "hateful": 0,
#     "targeted": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "multi_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 30002
# }
#
# loading weights file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/pytorch_model.bin from cache at /home/jmperez/.cache/huggingface/transformers/0f783b30471b13a04879e5c7f59ffb7e46b2aa6070bfc1de054e22f3730876b4.55428a0f24699e85f25e62ebe82b655dc72cfe0abf1f37e9b20c3d41978bbcf0
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at pysentimiento/robertuito-hate-speech.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
hate_speech_analyzer.predict("Esto es una mierda pero no es odio")
# Out:
# AnalyzerOutput(output=[], probas={hateful: 0.022, targeted: 0.009, aggressive: 0.018})

# %%
hate_speech_analyzer.predict("Esto es odio porque los inmigrantes deben ser aniquilados")
# Out:
# AnalyzerOutput(output=['hateful'], probas={hateful: 0.835, targeted: 0.008, aggressive: 0.476})

# %%
hate_speech_analyzer.predict("Vaya guarra barata y de poca monta es Miley Cyrus!")
# Out:
# AnalyzerOutput(output=['hateful', 'targeted', 'aggressive'], probas={hateful: 0.987, targeted: 0.978, aggressive: 0.969})

# %% [markdown]
# ## Preprocessing
#
# `pysentimiento` tiene un módulo de preprocesamiento de tweets con varias opciones para manipular hashtags, emojis, repetición de caracteres y demás.

# %%
from pysentimiento.preprocessing import preprocess_tweet

preprocess_tweet("📢 @realDonaldTrump ha sido banneado de Twitter #BreakingNews")
# Out:
# 'emoji altavoz de mano emoji  @usuario ha sido banneado de Twitter breaking news'
