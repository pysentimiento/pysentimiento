# %%
import json
evaluations = {

}

for model_name, path in [
    ('beto', '../../evaluations/hate_b_beto.json'),
    # Weighted hasta parece joder todo
    #('beto-weighted', '../../evaluations/hate_b_beto_weighted.json'),
    ('robertuito', '../../evaluations/robertuito-hate-speech-task-b.json'),
    ('robertuito-hier', '../../evaluations/robertuito-hate-speech-task-b-hier-loss.json'),
    ('robertuito-deacc', '../../evaluations/robertuito-deacc-hate-speech-task-b.json'),
    ]:
    with open(path) as f:
        evaluations[model_name] = json.load(f)


for key, evals in evaluations.items():
    print(f"We have {len(evals['evaluations']['hate_speech'])} {key} evaluations")
# Out:
# We have 10 beto evaluations
# We have 10 robertuito evaluations
# We have 4 robertuito-hier evaluations
# We have 10 robertuito-deacc evaluations

# %%
import pandas as pd


dfs = []
for model_name, model_results in evaluations.items():
    model_evaluations = model_results["evaluations"]["hate_speech"]
    
    if not model_evaluations:
        continue
    
    df = pd.DataFrame(model_evaluations)

    df.columns = [x.split("_", 1)[1] if "_" in x else x for x in df.columns]
    
    mean_df = pd.DataFrame({
        f"{model_name} mean": df.mean(), 
        f"{model_name} std": df.std()
    })
    dfs.append(mean_df)

result_df = pd.concat(dfs, axis=1)

result_df
# Out:
#                      beto mean   beto std  robertuito mean  robertuito std  \
# loss                  0.574698   0.055982         0.439435        0.058276
# hs_f1                 0.740107   0.008240         0.776361        0.004832
# hs_precision          0.666125   0.015305         0.703798        0.028920
# hs_recall             0.833182   0.016984         0.868939        0.040563
# tr_f1                 0.765947   0.007425         0.812015        0.007615
# tr_precision          0.784078   0.023008         0.824880        0.025821
# tr_recall             0.749173   0.009084         0.801182        0.030468
# ag_f1                 0.675184   0.020695         0.704510        0.013644
# ag_precision          0.588833   0.033052         0.618594        0.035878
# ag_recall             0.793038   0.016566         0.822152        0.035247
# macro_hs_f1_score     0.757266   0.010062         0.792068        0.007800
# emr_no_gating         0.653312   0.012822         0.684313        0.018132
# emr                   0.653938   0.012795         0.685187        0.018095
# macro_f1              0.727079   0.010179         0.764295        0.006589
# macro_precision       0.679679   0.017624         0.715757        0.027433
# macro_recall          0.791797   0.011019         0.830758        0.034001
# runtime               3.254040   0.075820         3.292170        0.062454
# samples_per_second  491.940700  11.670524       486.162100        9.365053
# steps_per_second     30.746400   0.729238        30.385000        0.585295
# epoch                 5.000000   0.000000         5.000000        0.000000
#
#                     robertuito-hier mean  robertuito-hier std  \
# loss                           17.532548             0.271888
# hs_f1                           0.774591             0.012390
# hs_precision                    0.746231             0.010500
# hs_recall                       0.805682             0.027030
# tr_f1                           0.628850             0.011093
# tr_precision                    0.476158             0.013125
# tr_recall                       0.926123             0.005242
# ag_f1                           0.623127             0.038780
# ag_precision                    0.473370             0.048203
# ag_recall                       0.917722             0.015407
# macro_hs_f1_score               0.802675             0.008999
# emr_no_gating                   0.466719             0.026690
# emr                             0.718750             0.009656
# macro_f1                        0.675523             0.019253
# macro_precision                 0.565253             0.021379
# macro_recall                    0.883175             0.009772
# runtime                         3.255975             0.092036
# samples_per_second            491.703000            13.889035
# steps_per_second               30.731500             0.867942
# epoch                           5.000000             0.000000
#
#                     robertuito-deacc mean  robertuito-deacc std
# loss                             0.507050              0.036590
# hs_f1                            0.779513              0.004851
# hs_precision                     0.720996              0.015884
# hs_recall                        0.848939              0.013553
# tr_f1                            0.805605              0.006967
# tr_precision                     0.830036              0.012609
# tr_recall                        0.782742              0.010241
# ag_f1                            0.714793              0.011205
# ag_precision                     0.651812              0.024441
# ag_recall                        0.792405              0.016104
# macro_hs_f1_score                0.799710              0.007551
# emr_no_gating                    0.692563              0.010191
# emr                              0.693250              0.010210
# macro_f1                         0.766637              0.005118
# macro_precision                  0.734281              0.012908
# macro_recall                     0.808029              0.010135
# runtime                          3.258660              0.093023
# samples_per_second             491.356400             13.902042
# steps_per_second                30.709700              0.868885
# epoch                            5.000000              0.000000
