# %%
import json
evaluations = {

}

for model_name, path in [
    ('beto', '../../evaluations/hate_b_beto.json'),
    # Weighted hasta parece joder todo
    ('beto-weighted', '../../evaluations/hate_b_beto_weighted.json')
    ]:
    with open(path) as f:
        evaluations[model_name] = json.load(f)


for key, evals in evaluations.items():
    print(f"We have {len(evals['evaluations']['hate_speech'])} {key} evaluations")
# Out:
# We have 10 beto evaluations
# We have 9 beto-weighted evaluations

# %%
import pandas as pd


dfs = []
for model_name, model_results in evaluations.items():
    model_evaluations = model_results["evaluations"]["hate_speech"]
    
    if not model_evaluations:
        continue
    
    df = pd.DataFrame(model_evaluations)

    df.columns = [x.split("_", 1)[1] if "_" in x else x for x in df.columns]
    
    mean_df = pd.DataFrame({
        f"{model_name} mean": df.mean(), 
        f"{model_name} std": df.std()
    })
    dfs.append(mean_df)

result_df = pd.concat(dfs, axis=1)

result_df
# Out:
#                      beto mean   beto std  beto-weighted mean  \
# loss                  0.574698   0.055982            0.706288
# hs_f1                 0.740107   0.008240            0.737867
# hs_precision          0.666125   0.015305            0.677033
# hs_recall             0.833182   0.016984            0.812626
# tr_f1                 0.765947   0.007425            0.758470
# tr_precision          0.784078   0.023008            0.761263
# tr_recall             0.749173   0.009084            0.757027
# ag_f1                 0.675184   0.020695            0.672121
# ag_precision          0.588833   0.033052            0.587880
# ag_recall             0.793038   0.016566            0.785748
# macro_hs_f1_score     0.757266   0.010062            0.759600
# emr_no_gating         0.653312   0.012822            0.658958
# emr                   0.653938   0.012795            0.661667
# macro_f1              0.727079   0.010179            0.722819
# macro_precision       0.679679   0.017624            0.675392
# macro_recall          0.791797   0.011019            0.785134
# runtime               3.254040   0.075820            3.233000
# samples_per_second  491.940700  11.670524          495.248556
# steps_per_second     30.746400   0.729238           30.953111
# epoch                 5.000000   0.000000            5.000000
#
#                     beto-weighted std
# loss                         0.068043
# hs_f1                        0.007160
# hs_precision                 0.023315
# hs_recall                    0.030586
# tr_f1                        0.009782
# tr_precision                 0.027715
# tr_recall                    0.024044
# ag_f1                        0.009662
# ag_precision                 0.018513
# ag_recall                    0.022823
# macro_hs_f1_score            0.010279
# emr_no_gating                0.017633
# emr                          0.018310
# macro_f1                     0.005857
# macro_precision              0.013280
# macro_recall                 0.020460
# runtime                      0.091256
# samples_per_second          13.996459
# steps_per_second             0.874847
# epoch                        0.000000
