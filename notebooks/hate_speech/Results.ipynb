# %%
import json
import pandas as pd

evaluations = {

}

for model_name, path in [
    ('beto', '../../evaluations/hate_speech/beto-taskb.json'),
    ('robertuito', '../../evaluations/hate_speech/robertuito-taskb.json'),
    ('robertuito-hier', '../../evaluations/hate_speech/robertuito-taskb-hier.json'),
    #('robertuito-deacc', '../../evaluations/robertuito-deacc-hate-speech-task-b.json'),
    ]:
    with open(path) as f:
        evaluations[model_name] = json.load(f)


for key, evals in evaluations.items():
    print(f"We have {len(evals['evaluations']['hate_speech'])} {key} evaluations")



dfs = []
for model_name, model_results in evaluations.items():
    model_evaluations = model_results["evaluations"]["hate_speech"]
    
    if not model_evaluations:
        continue
    
    df = pd.DataFrame(model_evaluations)

    df.columns = [x.split("_", 1)[1] if "_" in x else x for x in df.columns]
    
    mean_df = pd.DataFrame({
        f"{model_name} mean": df.mean(), 
        f"{model_name} std": df.std()
    })
    dfs.append(mean_df)

result_df = pd.concat(dfs, axis=1)
index = [
    'hs_f1', 'hs_precision', 'hs_recall', 'tr_f1',
    'ag_f1', 'macro_hs_f1_score',
    'emr_no_gating', 'emr', 
    'macro_f1',
]
result_df.loc[index]
# Out:
# We have 6 beto evaluations
# We have 10 robertuito evaluations
# We have 10 robertuito-hier evaluations
#                    beto mean  beto std  robertuito mean  robertuito std  \
# hs_f1               0.739819  0.010278         0.776505        0.004770
# hs_precision        0.669391  0.018223         0.696542        0.019935
# hs_recall           0.828283  0.032871         0.878485        0.022987
# tr_f1               0.757024  0.014506         0.808900        0.005051
# ag_f1               0.689911  0.008439         0.703604        0.005369
# macro_hs_f1_score   0.758199  0.010107         0.790274        0.008576
# emr_no_gating       0.657500  0.016474         0.676875        0.013652
# emr                 0.658333  0.016118         0.677625        0.013571
# macro_f1            0.728918  0.010286         0.763003        0.004019
#
#                    robertuito-hier mean  robertuito-hier std
# hs_f1                          0.780669             0.003177
# hs_precision                   0.733565             0.030827
# hs_recall                      0.837576             0.041530
# tr_f1                          0.812730             0.007353
# ag_f1                          0.702251             0.018617
# macro_hs_f1_score              0.803078             0.006420
# emr_no_gating                  0.404563             0.043760
# emr                            0.707937             0.018234
# macro_f1                       0.765217             0.007684

# %%
# Out:
# Index(['loss', 'hs_f1', 'hs_precision', 'hs_recall', 'tr_f1', 'tr_precision',
#        'tr_recall', 'ag_f1', 'ag_precision', 'ag_recall', 'macro_hs_f1_score',
#        'emr_no_gating', 'emr', 'macro_f1', 'macro_precision', 'macro_recall',
#        'runtime', 'samples_per_second', 'steps_per_second', 'epoch'],
#       dtype='object')
